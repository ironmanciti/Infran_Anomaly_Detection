# %% [markdown]
# # Fraud Detection with Variational Autoencoder

# %% [markdown]
# - VAE는 vanilla 오토인코더에 비해 훨씬 나은 성능의 이상탐지(anomaly detection) 성능을 제공합니다. 실험을 통해 우리는 기존의 AE는 너무 큰 bottleneck을 가지면 identity function이 되며 이상탐지 성능이 떨어지는 것에 반해, VAE는 bottleneck의 크기가 커질수록 이상탐지 성능이 오르는 효과를 갖는 것을 확인할 수 있습니다. 따라서 AE 기반의 anomaly detection을 수행할 때, 기존에는 bottleneck의 크기를 hyper-parameter로 튜닝해야 했던 반면에, VAE의 경우에는 튜닝을 할 필요가 거의 없습니다.
#
# - 신용 카드 데이터에 VAE(Variational Autoencoder)를 적용합니다.
#
#
# - 분포를 배우는 것이 좋은 점은,
#     첫째, 데이터 및 노이즈 생성 프로세스를 명시적으로 모델링함으로써 VAE는 더 robust 하게 그 두가지를 분리하는 방법을 배울 수 있습니다.
#     둘째, disentanglement constraint가 적용되면 잠재 공간이 더 해석 가능해집니다.
#     셋째, 잠재 벡터를 샘플링하여 새 샘플을 생성하고 디코더를 통해 파이프할 수 있습니다.
#
#
# * disentanglement : latent space가 linear한 구조를 가지게 되어서 하나의 latent vector z 를 움직였을 때 정해진 어떠한 하나의 특성이 변경되게 만들고자 하는 것. 예를 들어, latent vector z 의 specific 한 값을 변경했을 때 생성되는 이미지는 하나의 특성들(머리카락 길이, 성별, 사람의 시선)만 영향을 주게 만들었다고 하면, 이 모델의 latent space는 disentanglement 하다고 말 할 수 있다.
#
# ### Contents
#
# 1. Variational Autoencoder 훈련
# 2. 잠재 표현 시각화 (Visualize Latent Representations)
# 3. VAE model 훈련
# 4. 재구성 오류 계산
# 5. 테스트 세트에 대한 평가

# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, \
                            precision_score, recall_score
from sklearn.preprocessing import StandardScaler

np.random.seed(0)
tf.random.set_seed(0)

# %% [markdown]
# ## Raw Dataset
#
# model train 은 train set 만으로 합니다. test set은 최종 평가 때까지 사용되지 않습니다.

# %%
df = pd.read_csv('https://storage.googleapis.com/download.tensorflow.org/data/creditcard.csv')

df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# -  데이터 세트가 매우 불균형합니다.

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
fraud = (df['Class'] == 1).sum()
normal = (df['Class'] == 0).sum()

total = fraud + normal

print(f"Total = {total:,}")
print(f"Fraud = {fraud/total*100:,.2f}%")
print(f"Normal = {normal/total*100:,.2f}%")
# Out:
# Total = 284,807
# Fraud = 0.17%
# Normal = 99.83%

# %% [markdown]
# - Time 필드를 일중 시간으로 변환합니다.
# - Amount 필드는 로그 스케일로 변환합니다.

# %%
df.loc[:, "Time"]   = df.loc[:, "Time"].apply(lambda x : x / 3600 % 24) #24 시간
df.loc[:, 'Amount'] = np.log(df.loc[:, 'Amount'] + 1)

# %% [markdown]
# - class 1 이 너무 적으므로 통상적인 7:3 대신 5:5 비율로 train, test set 분리

# %%
X_train, X_test, y_train, y_test = train_test_split(
                        df.drop('Class', axis=1), df['Class'],
                        test_size=0.5, random_state=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((142403, 30), (142404, 30), (142403,), (142404,))

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train.values)
X_test  = sc.transform(X_test.values)

# %%
y_train.value_counts() / y_train.count()
# Out:
# 0    0.998251
# 1    0.001749
# Name: Class, dtype: float64

# %%
y_test.value_counts() / y_test.count()
# Out:
# 0    0.998294
# 1    0.001706
# Name: Class, dtype: float64

# %% [markdown]
# ## Variational Autoencoder 훈련
#
# - 디코더의 출력인 데이터 분포 매개 변수는 정규 분포를 따릅니다.  신용카드 데이터는 실수 값이며 일반적으로 정규 분포를 따르므로 정규 분포를 사용하여 출력을 모델링하는 것이 합리적입니다.

# %% [markdown]
# train set 을 정상과 비정상 set 으로 구분

# %%
X_train_normal = X_train[y_train == 0]
X_train_fraud = X_train[y_train == 1]

X_train_normal.shape, X_train_fraud.shape
# Out:
# ((142154, 30), (249, 30))

# %% [markdown]
# test set을 정상과 비정상 set으로 구분

# %%
X_test_normal = X_test[y_test == 0]
X_test_fraud = X_test[y_test == 1]

X_test_normal.shape, X_test_fraud.shape
# Out:
# ((142161, 30), (243, 30))

# %% [markdown]
# ### 데이터 파이프라인 작성

# %%
train_ds = tf.data.Dataset.from_tensor_slices(X_train_normal).shuffle(10000).batch(128)
test_ds = tf.data.Dataset.from_tensor_slices(X_test_normal).batch(128)

# %% [markdown]
# ## 신경망 구조 정의
#
# ![image.png](attachment:125daa9c-fe52-4e19-91ed-7f292b2b7ac7.png)
#
# ### Sampling Class
#
# 먼저 'Sampling' 클래스를 빌드합니다. 이것은 인코더 출력의 평균 (mu) 및 표준 편차 (sigma)와 함께 가우스 노이즈 입력을 제공하는 맞춤형 Keras 레이어입니다. 실제로 이 레이어의 출력은 다음 방정식으로 제공됩니다.
#
# $$z = \mu + e^{0.5\sigma} * \epsilon  $$
#
# 여기서 $\mu$ = mean, $\sigma$ = standard deviation, $\epsilon$ = random sample

# %%
class Sampling(tf.keras.layers.Layer):
    def call(self, inputs):
        """인코더의 출력과 결합하여 무작위 샘플을 생성합니다.
        Args:
          inputs -- 인코더로부터의 출력 텐서 (평균 mu, 표준편차 sigma)
        Returns:
          무작위 샘플이 결합된 `inputs` 텐서
        """
        # 인코더의 출력을 분해합니다.
        mu, sigma = inputs

        # 배치의 크기와 차원을 얻습니다.
        batch = tf.shape(mu)[0]
        dim = tf.shape(mu)[1]

        # 무작위 텐서를 생성합니다.
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))

        # 재매개변수화 기법을 적용합니다.
        return mu + tf.math.exp(0.5 * sigma) * epsilon

# %% [markdown]
# ### Kullback–Leibler Divergence
# 모델의 생성 능력을 향상 시키려면 잠재 공간에 도입된 랜덤 정규 분포를 고려해야 합니다. 이를 위해 [Kullback–Leibler Divergence](https://arxiv.org/abs/2002.07514)가 계산되어 재구성 손실에 추가됩니다. 공식은 아래 함수에서 정의됩니다.

# %%
def kl_reconstruction_loss(inputs, outputs, mu, sigma):
    """Kullback-Leibler 발산(KLD) 계산
    Args:
    inputs -- 데이터셋 배치
    outputs -- Sampling 층의 출력
    mu -- 평균
    sigma -- 표준 편차

    Returns:
    KLD 손실
    """
    # KLD 계산 공식 적용
    kl_loss = 1 + sigma - tf.square(mu) - tf.math.exp(sigma)
    # 배치 내 평균을 계산하고 -0.5를 곱하여 최종 KLD 손실을 계산
    kl_loss = tf.reduce_mean(kl_loss) * -0.5

    return kl_loss

# %% [markdown]
# ### VAE Model
# 이제 전체 VAE 모델을 정의할 수 있습니다. KL reconstruction loss를 추가하기 위해 `model.add_loss()`를 사용합니다. 이 손실을 계산하는 것은 `y_true`와 `y_pred`를 사용하지 않으므로 `model.compile()`에서 사용할 수 없습니다.
#
# - add_loss() 메서드 : 손실이 있는 경우, 자동으로 합산되어 주 손실에 추가

# %%
LATENT_DIM = 2
input_dim = X_train_normal.shape[-1]

# %%
encoder_input = Input(shape=(input_dim,))
x = Dense(32, activation='relu')(encoder_input)
x = Dense(16, activation='relu')(x)
mu = Dense(LATENT_DIM)(x)
sigma = Dense(LATENT_DIM)(x)

z = Sampling()((mu, sigma))

encoder = Model(encoder_input, [mu, sigma, z])

# %%
decoder_input = Input(shape=(LATENT_DIM,))
x = Dense(16, activation='relu')(decoder_input)
x = Dense(32, activation='relu')(x)
decoded = Dense(input_dim, activation='sigmoid')(x)

decoder = Model(decoder_input, decoded)

# %%
vae_input = encoder_input
# 인코더를 통과시켜 평균(mu), 표준 편차(sigma), 그리고 잠재 공간의 벡터(z)를 얻습니다.
mu, sigma, z = encoder(vae_input)
# 디코더를 사용하여 잠재 공간의 벡터(z)로부터 입력을 재구성
reconstructed = decoder(z)

# 입력과 재구성된 값을 사용하여 VAE 모델을 생성
vae = Model(vae_input, reconstructed)
# Kullback-Leibler 발산을 계산하는 함수를 사용하여 손실을 추가합니다. 이는 잠재 공간의 분포가
# 우리가 원하는 분포(예: 표준 정규 분포)에 가까워지도록 돕습니다.
loss = kl_reconstruction_loss(vae_input, z, mu, sigma)
# add_loss는 사용자 정의 손실을 추가하는 메서드
vae.add_loss(loss)

# %%
learning_rate = 0.001
optimizer = Adam(learning_rate=learning_rate)

# 학습 과정에서의 평균 손실을 추적
loss_metric = tf.keras.metrics.Mean()
# 평균 제곱 오차 손실 함수를 사용합니다.
mse_loss = tf.keras.losses.MeanSquaredError()

# %%
s = time.time()

epochs = 40

@tf.function
def train_step(x_batch_train):
    with tf.GradientTape() as tape:
        # VAE 모델에 배치 입력을 공급하여 재구성된 결과를 얻음
        reconstructed = vae(x_batch_train)

        # 재구성 손실을 계산
        loss = mse_loss(x_batch_train, reconstructed)

        # KLD 정규화 손실을 추가
        loss += sum(vae.losses)  # vae.losses에는 KLD 손실이 포함됨

    # 그라디언트를 계산하고 가중치 업데이트
    grads = tape.gradient(loss, vae.trainable_weights)
    optimizer.apply_gradients(zip(grads, vae.trainable_weights))
    return loss

# 테스트 스텝 추가
@tf.function
def test_step(x_batch_test):
    reconstructed = vae(x_batch_test)
    loss = mse_loss(x_batch_test, reconstructed)
    loss += sum(vae.losses)
    return loss

# 손실 지표를 두 개로 분리
train_loss_metric = tf.keras.metrics.Mean()
test_loss_metric = tf.keras.metrics.Mean()

for epoch in range(epochs):
    print('Start of epoch %d' % (epoch,))

    # 에포크 시작 시 지표 리셋
    train_loss_metric.reset_states()
    test_loss_metric.reset_states()

    for step, (x_batch_train, x_batch_test) in enumerate(zip(train_ds, test_ds)):
        # 훈련 스텝
        train_loss = train_step(x_batch_train)
        train_loss_metric(train_loss)

        # 테스트 스텝
        test_loss = test_step(x_batch_test)
        test_loss_metric(test_loss)

        # 매 500 스텝마다 결과 표시
        if step % 500 == 0:
            print('Epoch: %s step: %s' % (epoch, step))
            print('Mean training loss = %s' % (train_loss_metric.result().numpy()))
            print('Mean test loss = %s' % (test_loss_metric.result().numpy()))
# Out:
# Start of epoch 0
# Epoch: 0 step: 0
# Mean training loss = 1.9450719
# Mean test loss = 1.5861776
# Epoch: 0 step: 500
# Mean training loss = 1.0373722
# Mean test loss = 1.0356143
# Epoch: 0 step: 1000
# Mean training loss = 0.99525434
# Mean test loss = 0.9875019
# Start of epoch 1
# Epoch: 1 step: 0
# Mean training loss = 0.85397524
# Mean test loss = 0.94383734
# Epoch: 1 step: 500
# Mean training loss = 0.96575594
# Mean test loss = 0.96837586
# Epoch: 1 step: 1000
# Mean training loss = 0.9606942
# Mean test loss = 0.953348
# Start of epoch 2
# Epoch: 2 step: 0
# Mean training loss = 1.7333534
# Mean test loss = 0.94336295
# Epoch: 2 step: 500
# Mean training loss = 0.96882606
# Mean test loss = 0.96821415
# Epoch: 2 step: 1000
# Mean training loss = 0.9618094
# Mean test loss = 0.95323545
# Start of epoch 3
# Epoch: 3 step: 0
# Mean training loss = 0.8881352
# Mean test loss = 0.94325626
# Epoch: 3 step: 500
# Mean training loss = 0.9619494
# Mean test loss = 0.96818984
# Epoch: 3 step: 1000
# Mean training loss = 0.95964676
# Mean test loss = 0.95322037
# Start of epoch 4
# Epoch: 4 step: 0
# Mean training loss = 0.7026725
# Mean test loss = 0.9432477
# Epoch: 4 step: 500
# Mean training loss = 0.962063
# Mean test loss = 0.9681889
# Epoch: 4 step: 1000
# Mean training loss = 0.961979
# Mean test loss = 0.9532154
# Start of epoch 5
# Epoch: 5 step: 0
# Mean training loss = 0.9207125
# Mean test loss = 0.9432459
# Epoch: 5 step: 500
# Mean training loss = 0.96334815
# Mean test loss = 0.9681844
# Epoch: 5 step: 1000
# Mean training loss = 0.9611853
# Mean test loss = 0.9532156
# Start of epoch 6
# Epoch: 6 step: 0
# Mean training loss = 0.9699874
# Mean test loss = 0.94322896
# Epoch: 6 step: 500
# Mean training loss = 0.96379864
# Mean test loss = 0.9681765
# Epoch: 6 step: 1000
# Mean training loss = 0.9650973
# Mean test loss = 0.95320433
# Start of epoch 7
# Epoch: 7 step: 0
# Mean training loss = 0.8988927
# Mean test loss = 0.94331324
# Epoch: 7 step: 500
# Mean training loss = 0.96453613
# Mean test loss = 0.96817243
# Epoch: 7 step: 1000
# Mean training loss = 0.9613287
# Mean test loss = 0.95320517
# Start of epoch 8
# Epoch: 8 step: 0
# Mean training loss = 1.657244
# Mean test loss = 0.9432566
# Epoch: 8 step: 500
# Mean training loss = 0.96201813
# Mean test loss = 0.96817833
# Epoch: 8 step: 1000
# Mean training loss = 0.9611864
# Mean test loss = 0.9532065
# Start of epoch 9
# Epoch: 9 step: 0
# Mean training loss = 0.86332214
# Mean test loss = 0.94320786
# Epoch: 9 step: 500
# Mean training loss = 0.96396583
# Mean test loss = 0.96817243
# Epoch: 9 step: 1000
# Mean training loss = 0.96242964
# Mean test loss = 0.9532042
# Start of epoch 10
# Epoch: 10 step: 0
# Mean training loss = 1.353791
# Mean test loss = 0.94330394
# Epoch: 10 step: 500
# Mean training loss = 0.96216685
# Mean test loss = 0.9681718
# Epoch: 10 step: 1000
# Mean training loss = 0.9608062
# Mean test loss = 0.95320517
# Start of epoch 11
# Epoch: 11 step: 0
# Mean training loss = 1.1554303
# Mean test loss = 0.94318974
# Epoch: 11 step: 500
# Mean training loss = 0.96201134
# Mean test loss = 0.9681723
# Epoch: 11 step: 1000
# Mean training loss = 0.9623772
# Mean test loss = 0.9532042
# Start of epoch 12
# Epoch: 12 step: 0
# Mean training loss = 0.93886065
# Mean test loss = 0.94327444
# Epoch: 12 step: 500
# Mean training loss = 0.9666323
# Mean test loss = 0.9681733
# Epoch: 12 step: 1000
# Mean training loss = 0.9612531
# Mean test loss = 0.9532058
# Start of epoch 13
# Epoch: 13 step: 0
# Mean training loss = 0.95106083
# Mean test loss = 0.94329447
# Epoch: 13 step: 500
# Mean training loss = 0.9651852
# Mean test loss = 0.9681738
# Epoch: 13 step: 1000
# Mean training loss = 0.9647496
# Mean test loss = 0.9532044
# Start of epoch 14
# Epoch: 14 step: 0
# Mean training loss = 0.73681664
# Mean test loss = 0.9432349
# Epoch: 14 step: 500
# Mean training loss = 0.9631531
# Mean test loss = 0.9681765
# Epoch: 14 step: 1000
# Mean training loss = 0.9628171
# Mean test loss = 0.9532048
# Start of epoch 15
# Epoch: 15 step: 0
# Mean training loss = 1.0529321
# Mean test loss = 0.94328785
# Epoch: 15 step: 500
# Mean training loss = 0.96979195
# Mean test loss = 0.968175
# Epoch: 15 step: 1000
# Mean training loss = 0.9617311
# Mean test loss = 0.953204
# Start of epoch 16
# Epoch: 16 step: 0
# Mean training loss = 0.84778315
# Mean test loss = 0.9431727
# Epoch: 16 step: 500
# Mean training loss = 0.96429527
# Mean test loss = 0.9681722
# Epoch: 16 step: 1000
# Mean training loss = 0.96216214
# Mean test loss = 0.95320237
# Start of epoch 17
# Epoch: 17 step: 0
# Mean training loss = 0.79918236
# Mean test loss = 0.9432534
# Epoch: 17 step: 500
# Mean training loss = 0.9635135
# Mean test loss = 0.9681735
# Epoch: 17 step: 1000
# Mean training loss = 0.9620602
# Mean test loss = 0.95320255
# Start of epoch 18
# Epoch: 18 step: 0
# Mean training loss = 1.0446223
# Mean test loss = 0.94318175
# Epoch: 18 step: 500
# Mean training loss = 0.9594006
# Mean test loss = 0.96817183
# Epoch: 18 step: 1000
# Mean training loss = 0.9661811
# Mean test loss = 0.95320106
# Start of epoch 19
# Epoch: 19 step: 0
# Mean training loss = 1.0700936
# Mean test loss = 0.943246
# Epoch: 19 step: 500
# Mean training loss = 0.9675387
# Mean test loss = 0.96817195
# Epoch: 19 step: 1000
# Mean training loss = 0.9594521
# Mean test loss = 0.95320296
# Start of epoch 20
# Epoch: 20 step: 0
# Mean training loss = 0.79107916
# Mean test loss = 0.9430881
# Epoch: 20 step: 500
# Mean training loss = 0.96007633
# Mean test loss = 0.9681706
# Epoch: 20 step: 1000
# Mean training loss = 0.96162844
# Mean test loss = 0.953202
# Start of epoch 21
# Epoch: 21 step: 0
# Mean training loss = 1.0164429
# Mean test loss = 0.94329405
# Epoch: 21 step: 500
# Mean training loss = 0.95701176
# Mean test loss = 0.9681708
# Epoch: 21 step: 1000
# Mean training loss = 0.9608149
# Mean test loss = 0.95320153
# Start of epoch 22
# Epoch: 22 step: 0
# Mean training loss = 1.0926797
# Mean test loss = 0.94321
# Epoch: 22 step: 500
# Mean training loss = 0.96277195
# Mean test loss = 0.9681756
# Epoch: 22 step: 1000
# Mean training loss = 0.9606895
# Mean test loss = 0.9532044
# Start of epoch 23
# Epoch: 23 step: 0
# Mean training loss = 0.7752845
# Mean test loss = 0.9432521
# Epoch: 23 step: 500
# Mean training loss = 0.9667221
# Mean test loss = 0.96817297
# Epoch: 23 step: 1000
# Mean training loss = 0.9638349
# Mean test loss = 0.9532023
# Start of epoch 24
# Epoch: 24 step: 0
# Mean training loss = 0.8541777
# Mean test loss = 0.94329244
# Epoch: 24 step: 500
# Mean training loss = 0.9667494
# Mean test loss = 0.96817183
# Epoch: 24 step: 1000
# Mean training loss = 0.9615777
# Mean test loss = 0.9532032
# Start of epoch 25
# Epoch: 25 step: 0
# Mean training loss = 0.8993106
# Mean test loss = 0.9431851
# Epoch: 25 step: 500
# Mean training loss = 0.9642741
# Mean test loss = 0.96817243
# Epoch: 25 step: 1000
# Mean training loss = 0.9633066
# Mean test loss = 0.9532026
# Start of epoch 26
# Epoch: 26 step: 0
# Mean training loss = 0.78434455
# Mean test loss = 0.9431361
# Epoch: 26 step: 500
# Mean training loss = 0.9607933
# Mean test loss = 0.9681698
# Epoch: 26 step: 1000
# Mean training loss = 0.96480894
# Mean test loss = 0.95320046
# Start of epoch 27
# Epoch: 27 step: 0
# Mean training loss = 0.9022892
# Mean test loss = 0.9432736
# Epoch: 27 step: 500
# Mean training loss = 0.963243
# Mean test loss = 0.9681694
# Epoch: 27 step: 1000
# Mean training loss = 0.96260643
# Mean test loss = 0.9532022
# Start of epoch 28
# Epoch: 28 step: 0
# Mean training loss = 0.77529716
# Mean test loss = 0.94325185
# Epoch: 28 step: 500
# Mean training loss = 0.96555984
# Mean test loss = 0.9681713
# Epoch: 28 step: 1000
# Mean training loss = 0.9635895
# Mean test loss = 0.95320183
# Start of epoch 29
# Epoch: 29 step: 0
# Mean training loss = 0.7820127
# Mean test loss = 0.943274
# Epoch: 29 step: 500
# Mean training loss = 0.96727204
# Mean test loss = 0.96816945
# Epoch: 29 step: 1000
# Mean training loss = 0.96186244
# Mean test loss = 0.95320034
# Start of epoch 30
# Epoch: 30 step: 0
# Mean training loss = 0.9880104
# Mean test loss = 0.94319916
# Epoch: 30 step: 500
# Mean training loss = 0.9644534
# Mean test loss = 0.9681722
# Epoch: 30 step: 1000
# Mean training loss = 0.9613849
# Mean test loss = 0.95320165
# Start of epoch 31
# Epoch: 31 step: 0
# Mean training loss = 0.8622248
# Mean test loss = 0.9432207
# Epoch: 31 step: 500
# Mean training loss = 0.9612211
# Mean test loss = 0.9681669
# Epoch: 31 step: 1000
# Mean training loss = 0.9617756
# Mean test loss = 0.953199
# Start of epoch 32
# Epoch: 32 step: 0
# Mean training loss = 0.92633045
# Mean test loss = 0.9431108
# Epoch: 32 step: 500
# Mean training loss = 0.95752484
# Mean test loss = 0.96817183
# Epoch: 32 step: 1000
# Mean training loss = 0.9600149
# Mean test loss = 0.95320404
# Start of epoch 33
# Epoch: 33 step: 0
# Mean training loss = 1.3997002
# Mean test loss = 0.94321793
# Epoch: 33 step: 500
# Mean training loss = 0.9645729
# Mean test loss = 0.96817
# Epoch: 33 step: 1000
# Mean training loss = 0.9621667
# Mean test loss = 0.95320106
# Start of epoch 34
# Epoch: 34 step: 0
# Mean training loss = 0.770013
# Mean test loss = 0.94325304
# Epoch: 34 step: 500
# Mean training loss = 0.96547115
# Mean test loss = 0.9681696
# Epoch: 34 step: 1000
# Mean training loss = 0.96186435
# Mean test loss = 0.9532007
# Start of epoch 35
# Epoch: 35 step: 0
# Mean training loss = 0.99194574
# Mean test loss = 0.9432163
# Epoch: 35 step: 500
# Mean training loss = 0.965535
# Mean test loss = 0.9681697
# Epoch: 35 step: 1000
# Mean training loss = 0.9631734
# Mean test loss = 0.9532007
# Start of epoch 36
# Epoch: 36 step: 0
# Mean training loss = 0.8353824
# Mean test loss = 0.943185
# Epoch: 36 step: 500
# Mean training loss = 0.9633131
# Mean test loss = 0.968172
# Epoch: 36 step: 1000
# Mean training loss = 0.96212935
# Mean test loss = 0.95320255
# Start of epoch 37
# Epoch: 37 step: 0
# Mean training loss = 1.493037
# Mean test loss = 0.943182
# Epoch: 37 step: 500
# Mean training loss = 0.9637765
# Mean test loss = 0.96816885
# Epoch: 37 step: 1000
# Mean training loss = 0.9638468
# Mean test loss = 0.95320183
# Start of epoch 38
# Epoch: 38 step: 0
# Mean training loss = 0.87212485
# Mean test loss = 0.9431592
# Epoch: 38 step: 500
# Mean training loss = 0.9643143
# Mean test loss = 0.96817124
# Epoch: 38 step: 1000
# Mean training loss = 0.9595391
# Mean test loss = 0.95320123
# Start of epoch 39
# Epoch: 39 step: 0
# Mean training loss = 0.80585456
# Mean test loss = 0.94319713
# Epoch: 39 step: 500
# Mean training loss = 0.96135914
# Mean test loss = 0.96817267
# Epoch: 39 step: 1000
# Mean training loss = 0.9625048
# Mean test loss = 0.95320225

# %%
print(f"경과 시간: {(time.time() - s) / 60} 분")
# Out:
# 경과 시간: 5.700808604558309 분

# %% [markdown]
# ## Reconstruction Error 시각화
#
# - Anomaly data 와의 bar chart 비교를 위해 정상 abnormal data 갯수 만큼의 임의의 normal sample 을 선택

# %%
# 정상 sample 무작위 sampling
idx = np.random.choice(len(X_train_normal), 250, replace=False)
Nom_data = X_train_normal[idx]
Nom_data.shape
# Out:
# (250, 30)

# %% [markdown]
# ### 정상 data 및 fraud data 의 autoencoder 재 구성값
# - 정상 data의 metric

# %%
# 정상 데이터의 재구성 결과 값
Nom_pred = vae.predict(Nom_data)
# 재구성 오류 -  input/output 간의 MSE 구하기
Nom_pred_mse = np.mean(np.power(Nom_data - Nom_pred, 2), axis=1)

print('Normal Metric')
Nom_pred_mse_df = pd.DataFrame({'Normal_mse': Nom_pred_mse})
Nom_pred_mse_df.describe()
# Out:
# 8/8 [==============================] - 0s 2ms/step
# Normal Metric
#        Normal_mse
# count  250.000000
# mean     0.817810
# std      0.819122
# min      0.225024
# 25%      0.447392
# 50%      0.610562
# 75%      0.951404
# max      6.902593

# %%
# 비정상 data의 재구성 결과값
ANom_pred = vae.predict(X_train_fraud)
# 재구성 오류 -  input/output 간의 MSE 구하기
ANom_pred_mse = np.mean(np.power(X_train_fraud - ANom_pred, 2), axis=1)

print('Anomaly Metric')
ANom_pred_mse_df = pd.DataFrame({'Anomaly_mse':ANom_pred_mse})
ANom_pred_mse_df.describe()
# Out:
# 8/8 [==============================] - 0s 2ms/step
# Anomaly Metric
#        Anomaly_mse
# count   249.000000
# mean     24.159482
# std      31.099247
# min       0.343728
# 25%       4.423460
# 50%       9.582622
# 75%      28.882666
# max     198.786527

# %% [markdown]
# ### MSE 분포 시각화 비교

# %%
plt.title('MSE compare')
plt.hist(Nom_pred_mse, bins=10, color='blue', histtype='step', label='normal')
plt.hist(ANom_pred_mse, bins=10, color='red', histtype='step', label='abnormal')
plt.xlabel('MSE')
plt.legend()
plt.show()

# %%
plt.boxplot([Nom_pred_mse, ANom_pred_mse])
plt.title('Normal vs Fraud')
plt.xticks(ticks=[1, 2], labels=['Normal', 'Fraud'])
plt.show()

# %% [markdown]
# ## 잠재 표현 (Latent Representations) 시각화

# %%
X_test.shape
# Out:
# (142404, 30)

# %%
latent_x_mean, latent_x_std, latent_x  = encoder(X_test)

# %%
# X_test의 잠재 표현 평균 계산
plt.scatter(latent_x_mean[:, 0], latent_x_mean[:, 1], c=y_test, cmap='RdYlGn_r', s=2)
plt.title('latent means')
plt.xlabel('mean[0]')
plt.ylabel('mean[1]')
plt.show()

# %% [markdown]
# 원점 [0,0] 평균 벡터 주변에서 사기와 사기가 아닌 트랜잭션 사이에는 분명한 구분이 있습니다. 이는 VAE가 의미있는 것을 학습하고 있다는 신호입니다.

# %%
# X_test의 잠재 표현 표준 편차 계산
plt.scatter(latent_x_std[:, 0], latent_x_std[:, 1], c=y_test, cmap='RdYlGn_r', s=2)
plt.title('latent standard deviations')
plt.xlabel('stddev[0]')
plt.ylabel('stddev[1]')
plt.show()

# %% [markdown]
# 빨간색으로 표시된 사기 거래의 표준 편차가 훨씬 더 흩어져 있고 사기 거래가 불규칙한 경향이 있다는 직관과 일치합니다.

# %%
# X_test의 잠재 표현 시각화
plt.scatter(latent_x[:, 0], latent_x[:, 1], c=y_test, cmap='RdYlGn_r', s=2)
plt.title('latent vector samples')
plt.xlabel('z[0]')
plt.ylabel('z[1]')
plt.show()

# %% [markdown]
# 샘플된 잠재 벡터 z입니다. 클러스터링 및 scattering은 이전 관찰과 일치합니다.

# %% [markdown]
# ##  Reconstruction error threshold
# - 정상 data 로만 train 한 vae model 의 재구성 결과의 원본과의 mse 차이를 기준으로 사기 거래 분류

# %%
# train set의 재구성 오류 계산 (0 - 정상, 1 - 사기)
predictions = vae.predict(X_train)

mse = np.mean(np.power(X_train - predictions, 2), axis=1)

error_df = pd.DataFrame({'reconstruction_error': mse, 'true_class': y_train})
error_df.head()
# Out:
# 4451/4451 [==============================] - 7s 2ms/step
#         reconstruction_error  true_class
# 269414              1.478431           0
# 75463               0.278276           0
# 99307               0.261846           0
# 212267              2.085990           0
# 157412              0.914773           0

# %%
desc = error_df.groupby('true_class').describe()
desc
# Out:
#            reconstruction_error                                            \
#                           count       mean        std       min       25%
# true_class
# 0                      142154.0   0.959470   2.885667  0.163148  0.439436
# 1                         249.0  24.159409  31.099405  0.343678  4.422391
#
#
#                  50%        75%         max
# true_class
# 0           0.629821   0.932370  264.367017
# 1           9.583277  28.881769  198.805165

# %% [markdown]
# 위에서 보듯 사기성이 아닌 거래의  오류는 사기성 거래 보다 낮습니다.
#
# - mean + 3*std를 threshold로 사용하여 test set의 재구성 error(squared error)가 threshold 보다 크면 fraud 거래로 분류합니다.
# - 1 std - 68%, 2 std - 96%, 3 std - 99.8%

# %%
mean = desc['reconstruction_error']['mean'][0]
std = desc['reconstruction_error']['std'][0]

thresholds = {'3sigma': mean + 3*std,
                   '2.5sigma': mean + 2.5*std,
                     "2sigma": mean + 2*std}
mean, std, thresholds
# Out:
# (0.9594704601064533,
#  2.885667285453775,
#  {'3sigma': 9.61647231646778,
#   '2.5sigma': 8.173638673740891,
#   '2sigma': 6.730805031014003})

# %% [markdown]
# - Test set을 이용하여 재구성 오류 계산
# - thrshold 별로 confusion matrix

# %%
thresholds = sorted(thresholds.items(), key=lambda kv: kv[1])

def model_predict(threshold, mse):
     predictions = [(lambda er: 1 if er > threshold else 0)(er) for er in mse]
     return predictions

for sigma, threshold in thresholds:

    test_predictions = vae.predict(X_test)
    mse = np.mean(np.power(X_test - test_predictions, 2), axis=1)
    y_pred = model_predict(threshold, mse)

    print("Precision {:.2f}".format(precision_score(y_test, y_pred)))
    print("Recall {:.2f}".format(recall_score(y_test, y_pred)))

    cm = confusion_matrix(y_test, y_pred)

    ax = sns.heatmap(cm, annot=True, fmt=',')
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')
    ax.xaxis.set_ticklabels(['Normal', 'Fraud'])
    ax.yaxis.set_ticklabels(['Normal', 'Fraud'])
    ax.set(yticks=[0.5, 1.5], xticks=[0.5, 1.5])
    ax.set_title(sigma)
    plt.show()
# Out:
# 4451/4451 [==============================] - 7s 2ms/step
# Precision 0.10
# Recall 0.61
# 4451/4451 [==============================] - 7s 2ms/step
# Precision 0.12
# Recall 0.56
# 4451/4451 [==============================] - 7s 2ms/step
